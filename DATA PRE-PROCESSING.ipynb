# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

from sklearn.linear_model import LogisticRegression
log=LogisticRegression()

from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# Simple imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#knn imputer
from sklearn.impute import KNNImputer

import warnings
warnings.filterwarnings("ignore")

# %%
data={"SibSp":[1,1,0,1,0,0],"Fare":[7.2500,71.2833,7.2950,53.1000,8.0500,8.4583],"Age":[22,38,26,35,35,np.NaN]}
data

X=pd.DataFrame(data)
X
# Out:
#    SibSp     Fare   Age
# 0      1   7.2500  22.0
# 1      1  71.2833  38.0
# 2      0   7.2950  26.0
# 3      1  53.1000  35.0
# 4      0   8.0500  35.0
# 5      0   8.4583   NaN

# %%
# iterative imputer

# %%
impute=IterativeImputer(lr)
impute.fit_transform(X)
# Out:
# array([[ 1.        ,  7.25      , 22.        ],
#        [ 1.        , 71.2833    , 38.        ],
#        [ 0.        ,  7.295     , 26.        ],
#        [ 1.        , 53.1       , 35.        ],
#        [ 0.        ,  8.05      , 35.        ],
#        [ 0.        ,  8.4583    , 30.70268349]])

# %%
impute=IterativeImputer(rfr)
impute.fit_transform(X)
# Out:
# array([[ 1.    ,  7.25  , 22.    ],
#        [ 1.    , 71.2833, 38.    ],
#        [ 0.    ,  7.295 , 26.    ],
#        [ 1.    , 53.1   , 35.    ],
#        [ 0.    ,  8.05  , 35.    ],
#        [ 0.    ,  8.4583, 32.15  ]])

# %%
# on the data

# %%
data=pd.read_table("C:/Users/rijul/Downloads/horse-colic.txt",delimiter=",",header=None,na_values="?")
data.shape
data.isnull().sum()
# Out:
# 0       1
# 1       0
# 2       0
# 3      60
# 4      24
# 5      58
# 6      56
# 7      69
# 8      47
# 9      32
# 10     55
# 11     44
# 12     56
# 13    104
# 14    106
# 15    247
# 16    102
# 17    118
# 18     29
# 19     33
# 20    165
# 21    198
# 22      1
# 23      0
# 24      0
# 25      0
# 26      0
# 27      0
# dtype: int64

# %%
# on default  settings
# by default ml algo is bayesianRidge
data.shape
data.isnull().sum()
impute=IterativeImputer()
pd.DataFrame(impute.fit_transform(data)).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-57b202e172a9> in <module>
#       1 # on default  settings
#       2 # by default ml algo is bayesianRidge
# ----> 3 data.shape
#       4 data.isnull().sum()
#       5 impute=IterativeImputer()
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
new=pd.read_csv("C:/Users/rijul/Downloads/Same_Score_FullData.csv")
new.iloc[:,1:]
# Out:
#     Section  Test1  Test2  Final
# 0         1     94     91     87
# 1         2     51     65     91
# 2         1     95     97     97
# 3         2     63     75     80
# 4         2     80     76     71
# 5         1     92     40     86
# 6         1     75     78     72
# 7         1     94     91     87
# 8         2     51     65     91
# 9         1     95     97     97
# 10        2     63     75     80
# 11        2     80     76     71
# 12        1     92     40     86
# 13        1     75     78     72

# %%
score=pd.read_csv("C:/Users/rijul/Downloads/Same_Missing_Score.csv")
score=score.iloc[:,1:]
score
# Out:
#     Section  Test1  Test2  Final
# 0       1.0     94     91     87
# 1       2.0     51     65     91
# 2       1.0     95     97     97
# 3       NaN     63     75     80
# 4       2.0     80     76     71
# 5       NaN     92     40     86
# 6       1.0     75     78     72
# 7       1.0     94     91     87
# 8       NaN     51     65     91
# 9       1.0     95     97     97
# 10      2.0     63     75     80
# 11      2.0     80     76     71
# 12      1.0     92     40     86
# 13      NaN     75     78     72

# %%
# on linear regression
impute=IterativeImputer(lr)
pd.DataFrame(impute.fit_transform(data)).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d485bcea0347> in <module>
#       1 # on linear regression
#       2 impute=IterativeImputer(lr)
# ----> 3 pd.DataFrame(impute.fit_transform(data)).head()
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in fit_transform(self, X, y)
#     605
#     606         X, Xt, mask_missing_values, complete_mask = (
# --> 607             self._initial_imputation(X, in_fit=True))
#     608
#     609         super()._fit_indicator(complete_mask)
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in _initial_imputation(self, X, in_fit)
#     510             force_all_finite = True
#     511
# --> 512         X = self._validate_data(X, dtype=FLOAT_DTYPES, order="F", reset=in_fit,
#     513                                 force_all_finite=force_all_finite)
#     514         _check_inputs_dtype(X, self.missing_values)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'dict'

# %%
# with logistic regression
impute=IterativeImputer(log)
pd.DataFrame(impute.fit_transform(score),columns=["Section","Test1","Test2","Final"])
# Out:
#     Section  Test1  Test2  Final
# 0       1.0   94.0   91.0   87.0
# 1       2.0   51.0   65.0   91.0
# 2       1.0   95.0   97.0   97.0
# 3       2.0   63.0   75.0   80.0
# 4       2.0   80.0   76.0   71.0
# 5       1.0   92.0   40.0   86.0
# 6       1.0   75.0   78.0   72.0
# 7       1.0   94.0   91.0   87.0
# 8       2.0   51.0   65.0   91.0
# 9       1.0   95.0   97.0   97.0
# 10      2.0   63.0   75.0   80.0
# 11      2.0   80.0   76.0   71.0
# 12      1.0   92.0   40.0   86.0
# 13      2.0   75.0   78.0   72.0

# %%
# on randomforest regressor
impute=IterativeImputer(rf)
pd.DataFrame(impute.fit_transform(data)).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a3bf86a4345d> in <module>
#       1 # on randomforest regressor
#       2 impute=IterativeImputer(rf)
# ----> 3 pd.DataFrame(impute.fit_transform(data)).head()
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in fit_transform(self, X, y)
#     605
#     606         X, Xt, mask_missing_values, complete_mask = (
# --> 607             self._initial_imputation(X, in_fit=True))
#     608
#     609         super()._fit_indicator(complete_mask)
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in _initial_imputation(self, X, in_fit)
#     510             force_all_finite = True
#     511
# --> 512         X = self._validate_data(X, dtype=FLOAT_DTYPES, order="F", reset=in_fit,
#     513                                 force_all_finite=force_all_finite)
#     514         _check_inputs_dtype(X, self.missing_values)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'dict'

# %%
# knn imputer

# %%
X
# print((26+35+22)/3)
# Out:
#    SibSp     Fare   Age
# 0      1   7.2500  22.0
# 1      1  71.2833  38.0
# 2      0   7.2950  26.0
# 3      1  53.1000  35.0
# 4      0   8.0500  35.0
# 5      0   8.4583   NaN

# %%
knn=KNNImputer(n_neighbors=2)
knn.fit_transform(X)
# Out:
# array([[ 1.    ,  7.25  , 22.    ],
#        [ 1.    , 71.2833, 38.    ],
#        [ 0.    ,  7.295 , 26.    ],
#        [ 1.    , 53.1   , 35.    ],
#        [ 0.    ,  8.05  , 35.    ],
#        [ 0.    ,  8.4583, 30.5   ]])
