# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
stores=pd.read_csv("C:/Users/rijul/Downloads/stores.csv")
stores
# Out:
#     Unnamed: 0 StoreCode         StoreName     StoreType Location  \
# 0            1    STR101  Electronics Zone  Electronincs    Delhi
# 1            2    STR102      Apparel Zone       Apparel    Delhi
# 2            3    STR103       Super Bazar  Super Market    Delhi
# 3            4    STR104      Super Market  Super Market    Delhi
# 4            5    STR105     Central Store  Super Market    Delhi
# 5            6    STR106      Apparel Zone       Apparel    Delhi
# 6            7    STR107     Fashion Bazar       Apparel    Delhi
# 7            8    STR108     Digital Bazar  Electronincs    Delhi
# 8            9    STR109  Electronics Zone  Electronincs  Chennai
# 9           10    STR110      Apparel Zone       Apparel  Chennai
# 10          11    STR111       Super Bazar  Super Market  Chennai
# 11          12    STR112      Super Market  Super Market  Chennai
# 12          13    STR113     Central Store  Super Market  Chennai
# 13          14    STR114      Apparel Zone       Apparel  Chennai
# 14          15    STR115     Fashion Bazar       Apparel  Chennai
# 15          16    STR116     Digital Bazar  Electronincs  Chennai
# 16          17    STR117  Electronics Zone  Electronincs   Mumbai
# 17          18    STR118      Apparel Zone       Apparel   Mumbai
# 18          19    STR119       Super Bazar  Super Market   Mumbai
# 19          20    STR120      Super Market  Super Market   Mumbai
# 20          21    STR121     Central Store  Super Market   Mumbai
# 21          22    STR122      Apparel Zone       Apparel   Mumbai
# 22          23    STR123     Fashion Bazar       Apparel   Mumbai
# 23          24    STR124     Digital Bazar  Electronincs   Mumbai
# 24          25    STR125  Electronics Zone  Electronincs  Kolkata
# 25          26    STR126      Apparel Zone       Apparel  Kolkata
# 26          27    STR127       Super Bazar  Super Market  Kolkata
# 27          28    STR128      Super Market  Super Market  Kolkata
# 28          29    STR129     Central Store  Super Market  Kolkata
# 29          30    STR130      Apparel Zone       Apparel  Kolkata
# 30          31    STR131     Fashion Bazar       Apparel  Kolkata
# 31          32    STR132     Digital Bazar  Electronincs  Kolkata
#
#     OperatingCost  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  \
# 0            21.0         60       160.0              110            3.90
# 1            21.0         60       160.0              110            3.90
# 2            22.8         40       108.0               93            3.85
# 3            21.4         60       258.0              110            3.08
# 4            18.7         80       360.0              175            3.15
# 5            18.1         60       225.0              105            2.76
# 6            14.3         80       360.0              245            3.21
# 7            24.4         40       146.7               62            3.69
# 8            22.8         40       140.8               95            3.92
# 9            19.2         60       167.6              123            3.92
# 10           17.8         60       167.6              123            3.92
# 11           16.4         80       275.8              180             NaN
# 12           17.3         80       275.8              180             NaN
# 13           15.2         80       275.8              180             NaN
# 14           10.4         80       472.0              205            2.93
# 15           10.4         80       460.0              215            3.00
# 16           14.7         80       440.0              230            3.23
# 17           32.4         40        78.7               66            4.08
# 18           30.4         40        75.7               52            4.93
# 19           33.9         40        71.1               65            4.22
# 20           21.5         40       120.1               97            3.70
# 21           15.5         80       318.0              150            2.76
# 22           15.2         80       304.0              150            3.15
# 23           13.3         80       350.0              245            3.73
# 24           19.2         80       400.0              175            3.08
# 25           27.3         40        79.0               66            4.08
# 26           26.0         40       120.3               91            4.43
# 27           30.4         40        95.1              113            3.77
# 28           15.8         80       351.0              264            4.22
# 29           19.7         60       145.0              175            3.62
# 30           15.0         80       301.0              335            3.54
# 31           21.4         40       121.0              109            4.11
#
#     ...  OnlinePresence  Tenure  StoreSegment   Range        Exp    Exp2  \
# 0   ...               1       4             4  Medium   25600.00   12100
# 1   ...               1       4             4  Medium   25600.00   12100
# 2   ...               1       4             1  Medium   11664.00    8649
# 3   ...               0       3             1  Medium   66564.00   12100
# 4   ...               0       3             2  Medium  129600.00   30625
# 5   ...               0       3             1  Medium   50625.00   11025
# 6   ...               0       3             4  Medium  129600.00   60025
# 7   ...               0       4             2  Medium   21520.89    3844
# 8   ...               0       4             2    High   19824.64    9025
# 9   ...               0       4             4    High   28089.76   15129
# 10  ...               0       4             4    High   28089.76   15129
# 11  ...               0       3             3    High   76065.64   32400
# 12  ...               0       3             3    High   76065.64   32400
# 13  ...               0       3             3    High   76065.64   32400
# 14  ...               0       3             4    High  222784.00   42025
# 15  ...               0       3             4    High  211600.00   46225
# 16  ...               0       3             4    High  193600.00   52900
# 17  ...               1       4             1     LOW    6193.69    4356
# 18  ...               1       4             2     LOW    5730.49    2704
# 19  ...               1       4             1     LOW    5055.21    4225
# 20  ...               0       3             1    High   14424.01    9409
# 21  ...               0       3             2    High  101124.00   22500
# 22  ...               0       3             2    High   92416.00   22500
# 23  ...               0       3             4    High  122500.00   60025
# 24  ...               0       3             2    High  160000.00   30625
# 25  ...               1       4             1     LOW    6241.00    4356
# 26  ...               1       5             2    High   14472.09    8281
# 27  ...               1       5             2     LOW    9044.01   12769
# 28  ...               1       5             4    High  123201.00   69696
# 29  ...               1       5             4    High   21025.00   30625
# 30  ...               1       5             4    High   90601.00  112225
# 31  ...               1       4             2    High   14641.00   11881
#
#    Ment.TotalSales  Ment.Total_Customers          New  Square
# 0         5.428835              4.791420    4096000.0   12100
# 1         5.428835              4.791420    4096000.0   12100
# 2         4.762203              4.530655    1259712.0    8649
# 3         6.366097              4.791420   17173512.0   12100
# 4         7.113787              5.593445   46656000.0   30625
# 5         6.082202              4.717694   11390625.0   11025
# 6         7.113787              6.257325   46656000.0   60025
# 7         5.274039              3.957892    3157114.6    3844
# 8         5.202366              4.562903    2791309.3    9025
# 9         5.513466              4.973190    4707843.8   15129
# 10        5.513466              4.973190    4707843.8   15129
# 11        6.509257              5.646216   20978903.5   32400
# 12        6.509257              5.646216   20978903.5   32400
# 13        6.509257              5.646216   20978903.5   32400
# 14        7.785993              5.896369  105154048.0   42025
# 15        7.719443              5.990726   97336000.0   46225
# 16        7.605905              6.126926   85184000.0   52900
# 17        4.285402              4.041240     487443.4    4356
# 18        4.230243              3.732511     433798.1    2704
# 19        4.142761              4.020726     359425.4    4225
# 20        4.933794              4.594701    1732323.6    9409
# 21        6.825624              5.313293   32157432.0   22500
# 22        6.723951              5.313293   28094464.0   22500
# 23        7.047299              6.257325   42875000.0   60025
# 24        7.368063              5.593445   64000000.0   30625
# 25        4.290840              4.041240     493039.0    4356
# 26        4.936531              4.497941    1740992.4    8281
# 27        4.564503              4.834588     860085.4   12769
# 28        7.054004              6.415069   43243551.0   69696
# 29        5.253588              5.593445    3048625.0   30625
# 30        6.701759              6.945150   27270901.0  112225
# 31        4.946087              4.776856    1771561.0   11881
#
# [32 rows x 23 columns]

# %%
stores=stores.iloc[:,1:]
stores.dropna(how="any",axis=0,inplace=True)
stores.head()
stores.shape
# Out:
# (29, 22)

# %%
palette="husl"
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <ipython-input-9-3ebde28a0743>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   palette="husl"("")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3ebde28a0743> in <module>
# ----> 1 palette="husl"("")
#
# TypeError: 'str' object is not callable

# %%
# BARPLOT AND COUNTPLOT

# %%
sns.barplot(x='time',y='tip',data=tips);

# %%
import numpy as np

# %%
sns.barplot(x='smoker',y='total_bill',data=tips,estimator=np.sum);
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.sum);


tips.groupby("sex").sum()["total_bill"]
# Out:
# sex
# Male      3256.82
# Female    1570.95
# Name: total_bill, dtype: float64

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
# COUNTPLOT

# %%
sns.countplot(x='smoker',data=tips)
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# BOXPLOT AND VIOLINPLOT

# %%
palette="husl","rainbow","coolwarm"
sns.boxplot(x="day",y="total_bill",data=tips,palette='coolwarm');
sns.boxplot(x="Location",y="TotalSales",data=stores,palette="husl")
# Out:
# <AxesSubplot:xlabel='Location', ylabel='TotalSales'>

# %%
# can do entire dataframe with orient ='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="day",y="total_bill",hue="smoker",data=tips,palette="husl");
sns.boxplot(x="time",y="total_bill",hue="sex",data=tips,palette="husl");

stores.head()
sns.boxplot(x="Location",y="TotalSales",data=stores,hue="StoreType");

# %%
#VIOLINPLOT

# %%
sns.violinplot(x="day",y="total_bill",data=tips,palette='rainbow')
#sns.violinplot(x="StoreType",y="TotalSales",data=stores)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#sns.violinplot(x="day",y="total_bill",data=tips,hue='sex',palette='Set1')
sns.violinplot(x="day",y="total_bill",data=tips,hue='sex',palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue=)

# %%
#STRIPPLOT AND SWARMPLOT

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex',palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex',palette='Set1',split=True)
# Out:
# C:\Users\rijul\anaconda3\lib\site-packages\seaborn\categorical.py:2802: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# SWARMPLOT

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette="Set1",split=True)
# Out:
# C:\Users\rijul\anaconda3\lib\site-packages\seaborn\categorical.py:2999: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# COMBINING CATEGORICAL PLOTS

# %%
sns.violinplot(x="tip",y="day",data=tips,palette='rainbow')
sns.swarmplot(x="tip",y="day",data=tips,color='black',size=3)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,color="black")
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
