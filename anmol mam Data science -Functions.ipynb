# %% [markdown]
# # pandas

# %%
import pandas as pd 

#series
sr=pd. Series(data,index,dtype)

# dataframe 
df=pd. DataFrame(data,index,columns,dtype)

# indexing - slicinmg 

# access 1 column from dataframe 
df["column name "]
df.iloc[:,1]
df.loc[:,"columnmname"]

# access multiplt coulumn 

df[["col-1","col-2","col-3"]]
df.iloc[:,3:7]
df.iloc[:,[2,3,7]]
df.loc[:,["col-1","col-2"]]

# create csv file
df.to_csv("filname.csv")

# read csv file 
df=pd.read_csv("name of file")

#delete nan value records
df=df.dropna()

#fill nan value with some value 
df=df.fillna("hello")

#sorting of dataframe 

# Ascending 
df.sort_values(["columnname1"])

# descending 
df.sort_values(["columnname1"],ascending=False)

# how to delete duplicate records

df=df.drop_duplicates()

df=df.drop_duplicates(subsets=["col-1","col-3"])

# groupby
df.groupby("city")["name"].count()

#value_counts()
df["city"].value_counts()

# count unique values in column
df["colname"].nunique()

# list of  unique values in column
df["colname"].unique()

# information of datframe 
df.info()

# shape of dataframe 
df.shape

# print first 5 records of datframe 
df. head()

# print last 5 records of datframe 
df.tail()

# descibe of datafrme 
df.describe

#rename of column heading 
df.rename(columns={'old name':'new name'},inplace=True)
df.replace(['old'], ['new'])

# reset the index
df=df.reset_index()

# copy of datframe
df.copy()

# query on dataframe 
df.query("salary>50000")
df.query("name=='anmol'")

a="anmol"
df.query("name==@a")

# or
df[df["salary"]>50000]

# merging of datfarme ( how="inner","outer","left","right")
pd.merge(df_1,df_2,on="common column name",how="left")

# concat. of dataframe
pd.conact(df_1,df_2,axis=0)   # no. of rows increase

pd.concat(df_1,df_2,axis=1)   # no.of columns increase

# %% [markdown]
# # Numpy

# %%
import numpy as np

# create 1D/ 2D array
arr=np.array(data)

#check item size of array
arr.itemsize

# check the dattaype of array
arr.dtype

#shape of array
arr.shape

#min/max/mean value of array
np.max(arr)
np.min(arr)
np.mean(arr)


# sum of array
np.sum(arr,axis=0)   # column addition
np.sum(arr,axis=1)   # row wise

# linspace

np.linspace("startvalue","endingvalue", "no. of values u want to create inbetween starting and ending ")

#random function to create array
np.random.randint(start,end value)

#vstack and hstack
np.vstack (arr_1,arr_2)

np.hstack(arr_1,arr_2)

#unique()
np.unique(arr,return_counts=True)

# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt

# 1. line graph 
plt.plot([y-axis])
plt.plot([x-axis],[y-axis],linewidth,color,)

# 2. Point graph

plt.scatter([x-axis],[y-axis])
plt.plot([x-axis],[y-axis],'ro'or'r+*')

# 3. Bar graph

plt.bar([x-axis],[y-axis])

# 4. Pie chat
plt.pie([],labels,color,startangle,shadow,explode)
plt.legend()

# 5.stackgraph

plt.stackplot([x-axis],[y-axis],[y-axis],[y-axis])


# 6. Histogram

plt.hist([])# histogram
plt.hist([x-axis],[b-axis])# if u pass two list it convert into bar graph


# box plot
plt.boxplot([x-axis],[y-axis])

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# line plot 
sns.lmplot([],[])

# kde plot 
sns.kdeplot([])

kdeplot([],[])

# factorplot-bar graph

sns.factorplot([],[])

# displot plot -histogram/rug/kde
sns.distplot([])

# rugplot
sns.rugplot([])

# count plot -bar graph
sns.countplot([])
