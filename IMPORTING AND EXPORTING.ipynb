# %%
import pandas as pd
pla=pd.read_csv("C:\\Users\\rijul\\Downloads\\Placement_Data.csv")
pla.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
# DELETION OF MISSING VALUES

# %%
# =how=any & axis = 0 maens that if python finds any missing value in any row. that particular row will get deleted
pla.dropna(how="any",axis=0,inplace=True)
pla.shape
# Out:
# (148, 15)

# %%
pla.dropna(how="all",axis=0).shape
# Out:
# (215, 15)

# %%
pla.dropna(how="any",axis=1).shape
# Out:
# (215, 14)

# %%
pla.dropna(how="all",axis=1).shape
# Out:
# (215, 15)

# %%
import pandas as pd
import numpy as np
car=pd.read_csv("C:/Users/rijul/Downloads/car_sales.csv")
car
# Out:
#       Manufacturer              Model  Sales in thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545       NaN
# 153  Volvo          S70                            15.245       NaN
# 154  Volvo          V70                            17.531       NaN
# 155  Volvo          C70                             3.493       NaN
# 156  Volvo          S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# x_4_year               36
# Vehicle type            0
# Price in thousands      2
# Engine size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# Latest Launch           0
# Unnamed: 15           157
# XX                     36
# dtype: int64

# %%
pla["salary"].mean()
# Out:
# 288655.4054054054

# %%
car["Manufacturer"].value_counts()
# Out:
# Ford             11
# Dodge            11
# Mercedes-Benz     9
# Chevrolet         9
# Toyota            9
# Nissan            7
# Chrysler          7
# Mitsubishi        7
# Volvo             6
# Pontiac           6
# Volkswagen        6
# Lexus             6
# Mercury           6
# Oldsmobile        6
# Saturn            5
# Honda             5
# Cadillac          5
# Plymouth          4
# Acura             4
# Buick             4
# Lincoln           3
# Audi              3
# BMW               3
# Hyundai           3
# Porsche           3
# Jeep              3
# Saab              2
# Subaru            2
# Jaguar            1
# Infiniti          1
# Name: Manufacturer, dtype: int64

# %%
car["Manufacturer"].fillna("BMW",inplace=True)

# %%
car=car.iloc[:,:15]
car.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# x_4_year              36
# Vehicle type           0
# Price in thousands     2
# Engine size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Curb weight            2
# Fuel capacity          1
# Fuel efficiency        3
# Latest Launch          0
# dtype: int64

# %%
car=car.iloc[:,:15]
car
# Out:
#       Manufacturer              Model  Sales in thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545       NaN
# 153  Volvo          S70                            15.245       NaN
# 154  Volvo          V70                            17.531       NaN
# 155  Volvo          C70                             3.493       NaN
# 156  Volvo          S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# EXPORTING THE FILE

# %%
pla.to_csv("C:\\\\Users\\\\rijul\\\\Downloads\\\\PLAAAA.DATA.csv")
#car.to_csv("C:\\Users\\rijul\\Downloads\\Cleaned_Car_Sales_Data.csv")

# %%
# importing txt file
placement=pd.read_table("C:\\Users\\rijul\\Downloads\\Placement.txt")
placement
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-64b416d42995> in <module>
#       1 # importing txt file
# ----> 2 placement=pd.read_table("C:\\Users\\rijul\\Downloads\\Placement.txt")
#       3 placement
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pla.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
pla.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64
