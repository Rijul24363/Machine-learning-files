# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car=pd.read_csv("C:/Users/rijul/Downloads/car_sales.csv")
car
# Out:
#       Manufacturer              Model  Sales in thousands  x_4_year  \
# 0    Acura          Integra                        16.919    16.360
# 1    Acura          TL                             39.384    19.875
# 2    Acura          CL                             14.114    18.225
# 3    Acura          RL                              8.588    29.725
# 4    Audi           A4                             20.397    22.255
# ..             ...                ...                 ...       ...
# 152  Volvo          V40                             3.545       NaN
# 153  Volvo          S70                            15.245       NaN
# 154  Volvo          V70                            17.531       NaN
# 155  Volvo          C70                             3.493       NaN
# 156  Volvo          S80                            18.969       NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
sns.heatmap(car.corr());

# %%
sns.heatmap(car.corr(),cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:>

# %%
pvcar=car.pivot_table(values='Sales in thousands',index='Price in thousands',columns='Fuel efficiency')
sns.heatmap(pvcar);

# %%
sns.heatmap(pvcar,cmap='rainbow',linecolor='white',linewidths=4)
# Out:
# <AxesSubplot:xlabel='Fuel efficiency', ylabel='Price in thousands'>
